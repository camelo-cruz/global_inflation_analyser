# %%
import pandas as pd
import numpy as np
import os

# %%
def index_cleaning(index_list:list) -> list:
    """
    This function takes the index list of any DataFrame, cleans it and returns it 
    to the calling function to replace the previous data index with the cleaned data index. 
    """
    outlist = []
    for country in index_list:
        if country[0:5] == "China":
            outlist.append(country.split(": ")[-1].replace(" ","_"))
        else:
            outlist.append(country.split(",")[0].replace(" ","_"))
    return outlist

# %%
data = pd.read_excel("../data/Consumer_Price_Index_CPI_Clothing.xlsx")

# %%
data.head()
# Out:
#                      Unnamed: 0  Jan 2000  Feb 2000  Mar 2000  Apr 2000  \
# 0  Afghanistan, Islamic Rep. of       NaN       NaN       NaN       NaN
# 1                       Albania       NaN       NaN       NaN       NaN
# 2                       Algeria       NaN       NaN       NaN       NaN
# 3           Antigua and Barbuda       NaN       NaN       NaN       NaN
# 4                     Argentina       NaN       NaN       NaN       NaN
#
#    May 2000  Jun 2000  Jul 2000  Aug 2000  Sep 2000  ...     Aug 2022  \
# 0       NaN       NaN       NaN       NaN       NaN  ...          NaN
# 1       NaN       NaN       NaN       NaN       NaN  ...   102.036985
# 2       NaN       NaN       NaN       NaN       NaN  ...   245.900000
# 3       NaN       NaN       NaN       NaN       NaN  ...   121.440000
# 4       NaN       NaN       NaN       NaN       NaN  ...  1067.525100
#
#       Sep 2022     Oct 2022     Nov 2022     Dec 2022     Jan 2023  \
# ...

# %%
data = pd.read_excel("../data/Consumer_Price_Index_CPI_Clothing.xlsx")
data.index = data["Unnamed: 0"]
data = data.drop(columns=["Unnamed: 0"])
data.columns = [c.strip().replace(" ","_") for c in data.columns.values.tolist()]
data.index = index_cleaning(data.index.tolist())
data.head()
# Out:
#                      Jan_2000  Feb_2000  Mar_2000  Apr_2000  May_2000  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN
# Albania                   NaN       NaN       NaN       NaN       NaN
# Algeria                   NaN       NaN       NaN       NaN       NaN
# Antigua_and_Barbuda       NaN       NaN       NaN       NaN       NaN
# Argentina                 NaN       NaN       NaN       NaN       NaN
#
#                      Jun_2000  Jul_2000  Aug_2000  Sep_2000  Oct_2000  ...  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN  ...
# Albania                   NaN       NaN       NaN       NaN       NaN  ...
# Algeria                   NaN       NaN       NaN       NaN       NaN  ...
# Antigua_and_Barbuda       NaN       NaN       NaN       NaN       NaN  ...
# Argentina                 NaN       NaN       NaN       NaN       NaN  ...
#
#                         Aug_2022     Sep_2022     Oct_2022     Nov_2022  \
# ...

# %%
len(data)
# Out:
# 163

# %%
data.head()
# Out:
#                      Unnamed: 0  Jan 2000  Feb 2000  Mar 2000  Apr 2000  \
# 0  Afghanistan, Islamic Rep. of       NaN       NaN       NaN       NaN
# 1                       Albania       NaN       NaN       NaN       NaN
# 2                       Algeria       NaN       NaN       NaN       NaN
# 3           Antigua and Barbuda       NaN       NaN       NaN       NaN
# 4                     Argentina       NaN       NaN       NaN       NaN
#
#    May 2000  Jun 2000  Jul 2000  Aug 2000  Sep 2000  ...     Aug 2022  \
# 0       NaN       NaN       NaN       NaN       NaN  ...          NaN
# 1       NaN       NaN       NaN       NaN       NaN  ...   102.036985
# 2       NaN       NaN       NaN       NaN       NaN  ...   245.900000
# 3       NaN       NaN       NaN       NaN       NaN  ...   121.440000
# 4       NaN       NaN       NaN       NaN       NaN  ...  1067.525100
#
#       Sep 2022     Oct 2022     Nov 2022     Dec 2022     Jan 2023  \
# ...

# %%
def index_cleaning(index_list:list) -> list:
    outlist = []
    for country in index_list:
        if country[0:5] == "China":
            outlist.append(country.split(": ")[-1].replace(" ","_"))
        else:
            outlist.append(country.split(",")[0].replace(" ","_"))
    return outlist

# %%
data.index = data["Unnamed: 0"]
data = data.drop(columns=["Unnamed: 0"])
data.columns = [c.strip().replace(" ","_") for c in data.columns.values.tolist()]
data.index = index_cleaning(data.index.tolist())

# %%
data.head()
# Out:
#                      Jan_2000  Feb_2000  Mar_2000  Apr_2000  May_2000  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN
# Albania                   NaN       NaN       NaN       NaN       NaN
# Algeria                   NaN       NaN       NaN       NaN       NaN
# Antigua_and_Barbuda       NaN       NaN       NaN       NaN       NaN
# Argentina                 NaN       NaN       NaN       NaN       NaN
#
#                      Jun_2000  Jul_2000  Aug_2000  Sep_2000  Oct_2000  ...  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN  ...
# Albania                   NaN       NaN       NaN       NaN       NaN  ...
# Algeria                   NaN       NaN       NaN       NaN       NaN  ...
# Antigua_and_Barbuda       NaN       NaN       NaN       NaN       NaN  ...
# Argentina                 NaN       NaN       NaN       NaN       NaN  ...
#
#                         Aug_2022     Sep_2022     Oct_2022     Nov_2022  \
# ...

# %%
data.loc["Hong_Kong"]
# Out:
# Jan_2000      NaN
# Feb_2000      NaN
# Mar_2000      NaN
# Apr_2000      NaN
# May_2000      NaN
#             ...
# Jan_2023    108.8
# Feb_2023    108.3
# Mar_2023    112.1
# Apr_2023      NaN
# May_2023      NaN
# Name: Hong_Kong, Length: 281, dtype: float64

# %%
available_period = []
for period in data.loc["Albania"].isna().tolist():
    if period == True:
        available_period.append(False)
    elif period == False:
        available_period.append(True)

# %%
available_period
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
data.columns.values[available_period]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_279/2397955340.py in <module>
# ----> 1 data.columns.values[available_period]
#
# NameError: name 'available_period' is not defined

# %%
input_countries = ["Brazil","Argentina","United States"]

# %%
data.loc[input_countries]
# Out:
#                Jan_2000  Feb_2000  Mar_2000  Apr_2000  May_2000  Jun_2000  \
# Unnamed: 0
# Brazil              NaN       NaN       NaN       NaN       NaN       NaN
# Argentina           NaN       NaN       NaN       NaN       NaN       NaN
# United States       NaN       NaN       NaN       NaN       NaN       NaN
#
#                Jul_2000  Aug_2000  Sep_2000  Oct_2000  ...     Aug_2022  \
# Unnamed: 0                                             ...
# Brazil              NaN       NaN       NaN       NaN  ...          NaN
# Argentina           NaN       NaN       NaN       NaN  ...  1067.525100
# United States       NaN       NaN       NaN       NaN  ...   108.061163
#
#                   Sep_2022    Oct_2022     Nov_2022     Dec_2022     Jan_2023  \
# Unnamed: 0
# Brazil                 NaN         NaN          NaN          NaN          NaN
# Argentina      1180.950600  1261.59850  1318.260900  1371.336800  1402.845000
# ...

# %%
data_country = {}
for country in input_countries:
    available_period = []
    for period in data.loc["Albania"].isna().tolist():
        if period == True:
            available_period.append(False)
        elif period == False:
            available_period.append(True)

    data_country[country] = data.columns.values[available_period]

# %%
"Jan_2007" in data_country["United States"]
# Out:
# True

# %%
input_dates = {"start":"Jan_2008","end":"Dec_2018"}
input_countries = ["Brazil","Argentina","United States"]
date_range = data.columns.values.tolist()
for country in input_countries: 
    if input_dates["start"] in data_country[country]:
        start_index = date_range.index(input_dates["start"])
# Out:
# start
# end

# %%
date_range = data.columns.values.tolist()

# %%
date_range.index("Jan_2008")
# Out:
# 96

# %%
import os

for subdir, dirs, files in os.walk('data/'):
    file_list =  [os.path.join(subdir, file) for file in files]

# %%
for subdir, dirs, files in os.walk('../data/'):
    print(files)
# Out:
# ['Consumer_Price_Index_CPI_Education.xlsx', 'Consumer_Price_Index_CPI_Misc_Goods_Services.xlsx', 'Consumer_Price_Index_CPI_Recreation_Culture.xlsx', 'Consumer_Price_Index_CPI_Food.xlsx', 'Consumer_Price_Index_CPI_Clothing.xlsx', 'Consumer_Price_Index_CPI_Alcoholic_Beverages.xlsx', 'Consumer_Price_Index_CPI_Communication.xlsx', 'Consumer_Price_Index_CPI_Transport.xlsx', 'Consumer_Price_Index_CPI_Housing_Energy.xlsx', 'Consumer_Price_Index_CPI_Health.xlsx', 'Consumer_Price_Index_CPI_Restaurants_Hotels.xlsx']

# %%
wanted_columns = data.columns.values[np.where(data.columns.values == "Jan_2000")[0][0]:np.where(data.columns.values == "Jan_2010")[0][0]]

# %%
np.where(data.columns.values == "Jan_2010")[0][0]
# Out:
# 120

# %%
data[wanted_columns]
# Out:
#                       Jan_2000   Feb_2000   Mar_2000  Apr_2000   May_2000  \
# Afghanistan                NaN        NaN        NaN       NaN        NaN
# Albania                    NaN        NaN        NaN       NaN        NaN
# Algeria                    NaN        NaN        NaN       NaN        NaN
# Antigua_and_Barbuda        NaN        NaN        NaN       NaN        NaN
# Argentina                  NaN        NaN        NaN       NaN        NaN
# ...                        ...        ...        ...       ...        ...
# Uzbekistan                 NaN        NaN        NaN       NaN        NaN
# Vietnam                    NaN        NaN        NaN       NaN        NaN
# West_Bank_and_Gaza   85.896377  85.126696  85.099924  83.50702  84.062528
# Zambia                     NaN        NaN        NaN       NaN        NaN
# Zimbabwe                   NaN        NaN        NaN       NaN        NaN
#
#                      Jun_2000   Jul_2000   Aug_2000   Sep_2000   Oct_2000  \
# ...

# %%
np.where(data.columns.values == "Jun_2015")
# Out:
# (array([185]),)

# %%
data.columns.values
# Out:
# array(['Jan_2000', 'Feb_2000', 'Mar_2000', 'Apr_2000', 'May_2000',
#        'Jun_2000', 'Jul_2000', 'Aug_2000', 'Sep_2000', 'Oct_2000',
#        'Nov_2000', 'Dec_2000', 'Jan_2001', 'Feb_2001', 'Mar_2001',
#        'Apr_2001', 'May_2001', 'Jun_2001', 'Jul_2001', 'Aug_2001',
#        'Sep_2001', 'Oct_2001', 'Nov_2001', 'Dec_2001', 'Jan_2002',
#        'Feb_2002', 'Mar_2002', 'Apr_2002', 'May_2002', 'Jun_2002',
#        'Jul_2002', 'Aug_2002', 'Sep_2002', 'Oct_2002', 'Nov_2002',
#        'Dec_2002', 'Jan_2003', 'Feb_2003', 'Mar_2003', 'Apr_2003',
#        'May_2003', 'Jun_2003', 'Jul_2003', 'Aug_2003', 'Sep_2003',
#        'Oct_2003', 'Nov_2003', 'Dec_2003', 'Jan_2004', 'Feb_2004',
#        'Mar_2004', 'Apr_2004', 'May_2004', 'Jun_2004', 'Jul_2004',
#        'Aug_2004', 'Sep_2004', 'Oct_2004', 'Nov_2004', 'Dec_2004',
#        'Jan_2005', 'Feb_2005', 'Mar_2005', 'Apr_2005', 'May_2005',
#        'Jun_2005', 'Jul_2005', 'Aug_2005', 'Sep_2005', 'Oct_2005',
# ...

# %%
print(data.head())
# Out:
#                      Jan_2000  Feb_2000  Mar_2000  Apr_2000  May_2000  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN
# Albania                   NaN       NaN       NaN       NaN       NaN
# Algeria                   NaN       NaN       NaN       NaN       NaN
# Antigua_and_Barbuda       NaN       NaN       NaN       NaN       NaN
# Argentina                 NaN       NaN       NaN       NaN       NaN
#
#                      Jun_2000  Jul_2000  Aug_2000  Sep_2000  Oct_2000  ...  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN  ...
# Albania                   NaN       NaN       NaN       NaN       NaN  ...
# Algeria                   NaN       NaN       NaN       NaN       NaN  ...
# Antigua_and_Barbuda       NaN       NaN       NaN       NaN       NaN  ...
# Argentina                 NaN       NaN       NaN       NaN       NaN  ...
#
#                         Aug_2022     Sep_2022     Oct_2022     Nov_2022  \
# ...

# %%
def file_list(directory):
        current_dir = os.path.dirname("__file__")
        data_dir = os.path.abspath(os.path.join(current_dir, os.pardir, 'data'))
        file_list = [os.path.join(data_dir, file) 
                        for file in os.listdir(data_dir)]
        
        return file_list

# %%
data_folder = "data/"
files = file_list(data_folder)

# %%
files
# Out:
# ['/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Education.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Misc_Goods_Services.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Recreation_Culture.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/~$Consumer_Price_Index_CPI_Health.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Food.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Clothing.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Alcoholic_Beverages.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Communication.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Transport.xlsx',
#  '/home/kshitij/global_inflation_analyser/data/Consumer_Price_Index_CPI_Housing_Energy.xlsx',
# ...

# %%
from preprocessor import Preprocessor

# %%
p = Preprocessor()
p.list_products()
# Out:
# ['Education',
#  'Misc_Goods_Services',
#  'Recreation_Culture',
#  'Food',
#  'Clothing',
#  'Alcoholic_Beverages',
#  'Communication',
#  'Transport',
#  'Housing_Energy',
#  'Health',
#  'Restaurants_Hotels']

# %%
from analysis import Analyser

# %%
an = Analyser()

# %%
an.list_products()
# Out:
# ['Education',
#  'Misc_Goods_Services',
#  'Recreation_Culture',
#  'Food',
#  'Clothing',
#  'Alcoholic_Beverages',
#  'Communication',
#  'Transport',
#  'Housing_Energy',
#  'Health',
#  'Restaurants_Hotels']

# %%
an.list_countries(intext="all")
# Out:
# ['Afghanistan',
#  'Albania',
#  'Antigua_and_Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia_and_Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British_Virgin_Islands',
#  'Brunei_Darussalam',
#  'Bulgaria',
#  'Burkina_Faso',
#  'Burundi',
#  'Cabo_Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central_African_Rep.',
#  'Chad',
#  'Chile',
#  'Hong_Kong',
#  'Macao',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa_Rica',
#  "Côte_d'Ivoire",
#  'Croatia',
#  'Cyprus',
#  'Czech_Rep.',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican_Rep.',
#  'Ecuador',
#  'Egypt',
#  'El_Salvador',
#  'Equatorial_Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Grenada',
# ...

# %%
an.list_years()
# Out:
# INFO:root:You have chosen the following countries : ['Afghanistan', 'Albania', 'Antigua_and_Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia_and_Herzegovina', 'Botswana', 'Brazil', 'British_Virgin_Islands', 'Brunei_Darussalam', 'Bulgaria', 'Burkina_Faso', 'Burundi', 'Cabo_Verde', 'Cambodia', 'Cameroon', 'Canada', 'Central_African_Rep.', 'Chad', 'Chile', 'Hong_Kong', 'Macao', 'Colombia', 'Comoros', 'Congo', 'Congo', 'Costa_Rica', "Côte_d'Ivoire", 'Croatia', 'Cyprus', 'Czech_Rep.', 'Denmark', 'Djibouti', 'Dominica', 'Dominican_Rep.', 'Ecuador', 'Egypt', 'El_Salvador', 'Equatorial_Guinea', 'Estonia', 'Eswatini', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti', 'Honduras', 'Hungary', 'Iceland', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jordan', 'K
# ...

# %%
data = an.set_datafile("Education",["Argentina","Belgium","Chile"],"Jan_2015","Jul_2017")
# Out:
# INFO:root:You have chosen the following countries : ['Argentina', 'Belgium', 'Chile']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2015 to Jun_2017

# %%
data
# Out:
#            Jan_2015  Feb_2015  Mar_2015  Apr_2015  May_2015  Jun_2015  \
# Argentina       NaN       NaN       NaN       NaN       NaN       NaN
# Belgium      102.55    102.55    102.55    102.55    102.55    102.55
# Chile         84.23     84.25     88.59     88.60     88.62     88.66
#
#            Jul_2015  Aug_2015  Sep_2015  Oct_2015  ...  Sep_2016  Oct_2016  \
# Argentina       NaN       NaN       NaN       NaN  ...       NaN       NaN
# Belgium      102.55    102.55    102.55    132.09  ...    132.09    132.09
# Chile         88.63     88.63     88.60     88.59  ...     92.96     92.97
#
#            Nov_2016  Dec_2016  Jan_2017  Feb_2017  Mar_2017  Apr_2017  \
# Argentina       NaN    100.00  100.7952  103.9808  115.3409  118.6783
# Belgium      132.09    132.09  132.0900  132.0900  132.0900  132.0900
# Chile         92.96     92.96   92.9800   93.0100   96.9700   96.9700
#
#            May_2017  Jun_2017
# Argentina    120.69  121.8757
# Belgium      132.09  132.0900
# ...

# %%
inf_data = an.inflation_calculator(data)

# %%
inf_data
# Out:
#            Jan_2015_INF  Feb_2015_INF  Mar_2015_INF  Apr_2015_INF  \
# Argentina           NaN           NaN           NaN           NaN
# Belgium             2.5           0.0           0.0           0.0
# Chile             -15.8           0.0           5.2           0.0
#
#            May_2015_INF  Jun_2015_INF  Jul_2015_INF  Aug_2015_INF  \
# Argentina           NaN           NaN           NaN           NaN
# Belgium             0.0           0.0           0.0           0.0
# Chile               0.0           0.0          -0.0           0.0
#
#            Sep_2015_INF  Oct_2015_INF  ...  Sep_2016_INF  Oct_2016_INF  \
# Argentina           NaN           NaN  ...           NaN           NaN
# Belgium             0.0          28.8  ...           0.0           0.0
# Chile              -0.0          -0.0  ...          -0.0           0.0
#
#            Nov_2016_INF  Dec_2016_INF  Jan_2017_INF  Feb_2017_INF  \
# Argentina           NaN           NaN           0.8           3.2
# ...

# %%
argentina_inf = an.all_products_inflation("Argentina","Jan_2010","Jan_2018")
# Out:
# INFO:root:You have chosen the following countries : ['Argentina']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2010 to Dec_2017
# INFO:root:You have chosen the following countries : ['Argentina']
# INFO:root:You have chosen Misc_Goods_Services
# INFO:root:You have chosen the time data from Jan_2010 to Dec_2017
# INFO:root:You have chosen the following countries : ['Argentina']
# INFO:root:You have chosen Recreation_Culture
# INFO:root:You have chosen the time data from Jan_2010 to Dec_2017
# INFO:root:You have chosen the following countries : ['Argentina']
# INFO:root:You have chosen Food
# INFO:root:You have chosen the time data from Jan_2010 to Dec_2017
# INFO:root:You have chosen the following countries : ['Argentina']
# INFO:root:You have chosen Clothing
# INFO:root:You have chosen the time data from Jan_2010 to Dec_2017
# INFO:root:You have chosen the following countries : ['Argentina']
# INFO:root:You have chosen Alcoholic_Beverages
# ...

# %%
argentina_inf
# Out:
#                      Jan_2010  Feb_2010  Mar_2010  Apr_2010  May_2010  \
# Education                 NaN       NaN       NaN       NaN       NaN
# Misc_Goods_Services       NaN       NaN       NaN       NaN       NaN
# Recreation_Culture        NaN       NaN       NaN       NaN       NaN
# Food                      NaN       NaN       NaN       NaN       NaN
# Clothing                  NaN       NaN       NaN       NaN       NaN
# Alcoholic_Beverages       NaN       NaN       NaN       NaN       NaN
# Communication             NaN       NaN       NaN       NaN       NaN
# Transport                 NaN       NaN       NaN       NaN       NaN
# Housing_Energy            NaN       NaN       NaN       NaN       NaN
# Health                    NaN       NaN       NaN       NaN       NaN
# Restaurants_Hotels        NaN       NaN       NaN       NaN       NaN
#
#                      Jun_2010  Jul_2010  Aug_2010  Sep_2010  Oct_2010  ...  \
# ...

# %%
data = an.by_country("Education","Argentina")
# Out:
# INFO:root:You have chosen the following countries : Argentina
# INFO:root:You have chosen Education

# %%
data
# Out:
# Jan_2000          NaN
# Feb_2000          NaN
# Mar_2000          NaN
# Apr_2000          NaN
# May_2000          NaN
#               ...
# Jan_2023     902.0686
# Feb_2023     930.4868
# Mar_2023    1201.1258
# Apr_2023    1261.5273
# May_2023          NaN
# Name: Argentina, Length: 281, dtype: float64

# %%
import numpy as np

# %%
np.where(data.columns.values == "Jan_2010")[0][0]
# Out:
# 120

# %%
s = "Jan_2010"
s.capitalize()
# Out:
# 'Jan_2010'

# %%
np.where(data.columns.values == s.capitalize())[0][0]
# Out:
# 120

# %%
product_list = an.list_products()
l_nation = ["Argentina"]

# resultframe = pd.DataFrame()

for product in product_list:             
    print(product)
    # result = an.set_datafile(product,l_nation,"Jan_2015","Jan_2016")
    # result.head()
# Out:
# Education
# Misc_Goods_Services
# Recreation_Culture
# Food
# Clothing
# Alcoholic_Beverages
# Communication
# Transport
# Housing_Energy
# Health
# Restaurants_Hotels

# %%
from preprocessor import Preprocessor

# %%
p = Preprocessor()

# %%
p.list_countries()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Antigua_and_Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia_and_Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British_Virgin_Islands',
#  'Brunei_Darussalam',
#  'Bulgaria',
#  'Burkina_Faso',
#  'Burundi',
#  'Cabo_Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central_African_Rep.',
#  'Chad',
#  'Chile',
#  'Hong_Kong',
#  'Macao',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa_Rica',
#  "Côte_d'Ivoire",
#  'Croatia',
#  'Cyprus',
#  'Czech_Rep.',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican_Rep.',
#  'Ecuador',
#  'Egypt',
#  'El_Salvador',
#  'Equatorial_Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Grenada',
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/product_group_CPI/africa_products_CPI/CPI_Education.csv")
data.head()
# Out:
#      Unnamed: 0    2013    2014    2015    2016    2017    2018    2019  \
# 0         Benin  100.31  100.01  100.54  100.67   99.33   99.62  101.34
# 1      Botswana   76.84   82.53   87.82   91.05   94.85  100.00  103.09
# 2  Burkina Faso     NaN     NaN  101.35  101.48  102.02  103.48  105.31
# 3       Burundi   95.00   95.96   98.44   99.68  113.83  136.55  139.58
# 4    Cabo Verde   97.90   97.19   96.26   96.33   98.04  100.00  100.11
#
#      2020    2021    2022
# 0  102.95  103.01  103.43
# 1  107.99  109.57  112.69
# 2  107.53  109.08  112.60
# 3  141.83  149.00  151.79
# 4   99.83   98.55     NaN

# %% [markdown]
# # Finding the inflation rate of Education in European Countries from January 2010 to December 2015

# %%
from analysis import Analyser

# %%
a = Analyser()

# %%
a.list_products()
# Out:
# ['Education',
#  'Misc_Goods_Services',
#  'Recreation_Culture',
#  'Food',
#  'Clothing',
#  'Alcoholic_Beverages',
#  'Communication',
#  'Transport',
#  'Housing_Energy',
#  'Health',
#  'Restaurants_Hotels']

# %%
europe_countries = a.list_countries(intext="Europe")
europe_countries
# Out:
# ['Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Czech_Rep.',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Montenegro',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Russian_Federation',
#  'Serbia',
#  'Spain',
#  'Switzerland',
#  'Ukraine',
#  'United_Kingdom']

# %%
data = a.set_datafile(product="Education",country_list=europe_countries,start_time="Jan_2010",stop_time="Dec_2015")
data.head()
# Out:
# INFO:root:You have chosen the following countries : ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czech_Rep.', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Russian_Federation', 'Serbia', 'Spain', 'Switzerland', 'Ukraine', 'United_Kingdom']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2010 to Nov_2015
#                 Jan_2010      Feb_2010  ...      Oct_2015      Nov_2015
# Austria        75.102260     75.345830  ...     90.980870     90.980870
# Belgium        96.670000     96.670000  ...    132.090000    132.090000
# Bulgaria    13708.720211  13742.611631  ...  16451.627033  16454.492837
# Croatia       112.800000    112.900000  ...     99.500000     99.500000
# Czech_Rep.     91.700000     91.800000  ...    100.800000    100.700000
#
# [5 rows x 71 columns]

# %%
inflation_data = a.inflation_calculator(data)
inflation_data
# Out:
#                     Jan_2010_INF  Feb_2010_INF  ...  Oct_2015_INF  Nov_2015_INF
# Austria                    -24.9           0.3  ...           0.1           0.0
# Belgium                     -3.3           0.0  ...          28.8           0.0
# Bulgaria                 13608.7           0.2  ...           0.4           0.0
# Croatia                     12.8           0.1  ...           0.0           0.0
# Czech_Rep.                  -8.3           0.1  ...           0.0          -0.1
# Denmark                    -16.8           0.0  ...           0.9           0.0
# Estonia                    122.0           0.0  ...          -0.1           0.0
# Finland                    -12.7           0.0  ...           0.0           0.0
# France                      -8.7           0.0  ...           0.2          -0.1
# Germany                      4.6           0.2  ...           0.2           0.1
# Greece                      14.6           0.0  ...           0.1           0.0
# ...
