# %%
import pandas as pd
import numpy as np
import os
from preprocessor import Preprocessor
from analysis import Analyser

# %% [markdown]
# # Finding the inflation rate of Education in European Countries from January 2010 to December 2015

# %%
from analysis import Analyser

# %%
a = Analyser()

# %%
a.list_products()
# Out:
# ['Education',
#  'Misc_Goods_Services',
#  'Recreation_Culture',
#  'Food',
#  'Clothing',
#  'Alcoholic_Beverages',
#  'Communication',
#  'Transport',
#  'Housing_Energy',
#  'Health',
#  'Restaurants_Hotels']

# %%
europe_countries = a.list_countries(intext="Europe")
europe_countries
# Out:
# ['Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Czech_rep.',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Montenegro',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Russian_federation',
#  'Serbia',
#  'Spain',
#  'Switzerland',
#  'Ukraine',
#  'United_kingdom']

# %%
data = a.set_datafile(product="Education",country_list=europe_countries,start_time="Jan_2010",stop_time="Dec_2015")
data.head()
# Out:
# INFO:root:You have chosen the following countries : ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czech_rep.', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Russian_federation', 'Serbia', 'Spain', 'Switzerland', 'Ukraine', 'United_kingdom']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2010 to Nov_2015
#                 Jan_2010      Feb_2010      Mar_2010      Apr_2010  \
# Austria        75.102260     75.345830     75.345830     75.427020
# Belgium        96.670000     96.670000     96.670000     96.670000
# Bulgaria    13708.720211  13742.611631  13744.339665  13744.339665
# Croatia       112.800000    112.900000    112.900000    112.900000
# Czech_rep.     91.700000     91.800000     91.800000     91.800000
#
#                 May_2010      Jun_2010      Jul_2010      Aug_2010  \
# ...

# %%
inflation_data = a.inflation_calculator(data)
inflation_data
# Out:
#                     Jan_2010_INF  Feb_2010_INF  Mar_2010_INF  Apr_2010_INF  \
# Austria                    -24.9           0.3           0.0           0.1
# Belgium                     -3.3           0.0           0.0           0.0
# Bulgaria                 13608.7           0.2           0.0           0.0
# Croatia                     12.8           0.1           0.0           0.0
# Czech_rep.                  -8.3           0.1           0.0           0.0
# Denmark                    -16.8           0.0           0.0           0.0
# Estonia                    122.0           0.0           0.0           0.1
# Finland                    -12.7           0.0           0.0           0.0
# France                      -8.7           0.0           0.3           0.0
# Germany                      4.6           0.2           0.0          -0.4
# Greece                      14.6           0.0           0.0           0.0
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
for country in europe_countries[::5]:
    plt.plot(inflation_data.columns.values.tolist()[1:],inflation_data.loc[country][1:],label=country);
plt.xticks(inflation_data.columns.values.tolist()[1::5],rotation=90);
plt.legend(loc="best")
plt.xlim(-1,len(inflation_data.columns.values.tolist()[1:]));

# %%
US_inf = a.all_products_inflation(nation="United_States",start_time="Jan_2022",stop_time="Dec_2022")
US_inf
# Out:
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Misc_Goods_Services
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Recreation_Culture
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Food
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Clothing
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# ...

# %%
from analysis import Analyser

# %%
a1 = Analyser()

# %%
a1.list_products()
# Out:
# ['Education',
#  'Misc_Goods_Services',
#  'Recreation_Culture',
#  'Food',
#  'Clothing',
#  'Alcoholic_Beverages',
#  'Communication',
#  'Transport',
#  'Housing_Energy',
#  'Health',
#  'Restaurants_Hotels']

# %%
a1.list_countries(intext="Europe")
# Out:
# ['Austria',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Czech_rep.',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Montenegro',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Russian_federation',
#  'Serbia',
#  'Spain',
#  'Switzerland',
#  'Ukraine',
#  'United_kingdom']

# %%
a1.list_years()
# Out:
# INFO:root:You have chosen the following countries : ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czech_rep.', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Russian_federation', 'Serbia', 'Spain', 'Switzerland', 'Ukraine', 'United_kingdom']
# INFO:root:You have chosen Education
# array(['Jan_2000', 'Feb_2000', 'Mar_2000', 'Apr_2000', 'May_2000',
#        'Jun_2000', 'Jul_2000', 'Aug_2000', 'Sep_2000', 'Oct_2000',
#        'Nov_2000', 'Dec_2000', 'Jan_2001', 'Feb_2001', 'Mar_2001',
#        'Apr_2001', 'May_2001', 'Jun_2001', 'Jul_2001', 'Aug_2001',
#        'Sep_2001', 'Oct_2001', 'Nov_2001', 'Dec_2001', 'Jan_2002',
#        'Feb_2002', 'Mar_2002', 'Apr_2002', 'May_2002', 'Jun_2002',
#        'Jul_2002', 'Aug_2002', 'Sep_2002', 'Oct_2002', 'Nov_2002',
#        'Dec_2002', 'Jan_2003', 'Feb_2003', 'Mar_2003', 'Apr_2003',
# ...

# %%
a1.by_product(product="")
# Out:
# No product provided. Here are your options :
# ['Education', 'Misc_Goods_Services', 'Recreation_Culture', 'Food', 'Clothing', 'Alcoholic_Beverages', 'Communication', 'Transport', 'Housing_Energy', 'Health', 'Restaurants_Hotels']

# %%
a1.by_product(product="Misc_Good_Services")
# Out:
# INFO:root:You have chosen Misc_Good_Services
# INFO:root:Misc_Good_Services is not a valid option.
# ['Education', 'Misc_Goods_Services', 'Recreation_Culture', 'Food', 'Clothing', 'Alcoholic_Beverages', 'Communication', 'Transport', 'Housing_Energy', 'Health', 'Restaurants_Hotels']

# %%
a1.by_product(product="food")
# Out:
# INFO:root:You have chosen food
# INFO:root:food is not a valid option.
# ['Education', 'Misc_Goods_Services', 'Recreation_Culture', 'Food', 'Clothing', 'Alcoholic_Beverages', 'Communication', 'Transport', 'Housing_Energy', 'Health', 'Restaurants_Hotels']

# %%
product_data = a1.by_product(product="Recreation_Culture")
product_data
# Out:
# INFO:root:You have chosen Recreation_Culture
#                       Jan_2000   Feb_2000   Mar_2000   Apr_2000   May_2000  \
# Afghanistan                NaN        NaN        NaN        NaN        NaN
# Albania                    NaN        NaN        NaN        NaN        NaN
# Algeria                    NaN        NaN        NaN        NaN        NaN
# Antigua_and_barbuda        NaN        NaN        NaN        NaN        NaN
# Argentina                  NaN        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...        ...
# Uzbekistan                 NaN        NaN        NaN        NaN        NaN
# Vietnam                    NaN        NaN        NaN        NaN        NaN
# West_bank_and_gaza   97.451857  99.153735  92.945748  93.351878  93.148813
# Zambia                     NaN        NaN        NaN        NaN        NaN
# Zimbabwe                   NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
a1.list_countries()
# Out:
# INFO:root:Additional options for regions :
# ['Africa', 'Asia', 'Europe', 'North_america', 'Oceania', 'South_america']
# ['Afghanistan',
#  'Albania',
#  'Antigua_and_barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia_and_herzegovina',
#  'Botswana',
#  'Brazil',
#  'British_virgin_islands',
#  'Brunei_darussalam',
#  'Bulgaria',
#  'Burkina_faso',
#  'Burundi',
#  'Cabo_verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central_african_rep.',
#  'Chad',
#  'Chile',
#  'Hong_kong',
#  'Macao',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Congo',
#  'Costa_rica',
#  "Côte_d'ivoire",
#  'Croatia',
#  'Cyprus',
#  'Czech_rep.',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican_rep.',
#  'Ecuador',
#  'Egypt',
#  'El_salvador',
#  'Equatorial_guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
# ...

# %%
a1.list_countries(intext="K*")
# Out:
# ['Kiribati', 'Korea', 'Kosovo', 'Kuwait', 'Kyrgyz_rep.']

# %%
a1.list_countries(intext="k")
# Out:
# ['Kiribati', 'Korea', 'Kosovo', 'Kuwait', 'Kyrgyz_rep.']

# %%
a1.list_countries(intext="North_america")
# Out:
# ['Bahamas',
#  'Barbados',
#  'Belize',
#  'British_virgin_islands',
#  'Canada',
#  'Costa_rica',
#  'Dominica',
#  'El_salvador',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'Mexico',
#  'Nicaragua',
#  'Panama',
#  'United_states']

# %%
country_list = a1.list_countries(intext="North_America")
country_list
# Out:
# ['Bahamas',
#  'Barbados',
#  'Belize',
#  'British_virgin_islands',
#  'Canada',
#  'Costa_rica',
#  'Dominica',
#  'El_salvador',
#  'Guatemala',
#  'Haiti',
#  'Honduras',
#  'Mexico',
#  'Nicaragua',
#  'Panama',
#  'United_states']

# %%
country_data = a1.by_country(product="Education",cl=country_list)
country_data
# Out:
# INFO:root:You have chosen the following countries : ['Bahamas', 'Barbados', 'Belize', 'British_virgin_islands', 'Canada', 'Costa_rica', 'Dominica', 'El_salvador', 'Guatemala', 'Haiti', 'Honduras', 'Mexico', 'Nicaragua', 'Panama', 'United_states']
# INFO:root:You have chosen Education
#                           Jan_2000    Feb_2000    Mar_2000    Apr_2000  \
# Bahamas                        NaN         NaN         NaN         NaN
# Barbados                       NaN         NaN         NaN         NaN
# Belize                         NaN   77.054898         NaN         NaN
# British_virgin_islands         NaN         NaN         NaN         NaN
# Canada                         NaN         NaN         NaN         NaN
# Costa_rica               18.152000   19.484000   19.628000   19.640000
# Dominica                       NaN         NaN         NaN         NaN
# El_salvador                    NaN         NaN         NaN         NaN
# ...

# %%
data = a1.by_country(product="Food",cl=["colombia"])
"Colombia" in data.index
# Out:
# INFO:root:You have chosen the following countries : ['Colombia']
# INFO:root:You have chosen Food
# True

# %%
[country for country in country_list if country not in country_data.index]
# Out:
# []

# %%
a1.by_country(product="Food",cl=["colomba"])
# Out:
# INFO:root:You have chosen the following countries : ['Colomba']
# INFO:root:You have chosen Food
# These countries are not available or misspelled:
#  ['Colomba']
# Empty DataFrame
# ...

# %%
a1.by_year(product="Education",cl=country_list,start="January_2010",stop="Jul_2010")
# Out:
# INFO:root:You have chosen the following countries : ['Bahamas', 'Barbados', 'Belize', 'British_virgin_islands', 'Canada', 'Costa_rica', 'Dominica', 'El_salvador', 'Guatemala', 'Haiti', 'Honduras', 'Mexico', 'Nicaragua', 'Panama', 'United_states']
# INFO:root:You have chosen Education
# Either January_2010 or Jul_2010 is incorrect.
# Available periods are :
# ['Jan_2000' 'Feb_2000' 'Mar_2000' 'Apr_2000' 'May_2000' 'Jun_2000'
#  'Jul_2000' 'Aug_2000' 'Sep_2000' 'Oct_2000' 'Nov_2000' 'Dec_2000'
#  'Jan_2001' 'Feb_2001' 'Mar_2001' 'Apr_2001' 'May_2001' 'Jun_2001'
#  'Jul_2001' 'Aug_2001' 'Sep_2001' 'Oct_2001' 'Nov_2001' 'Dec_2001'
#  'Jan_2002' 'Feb_2002' 'Mar_2002' 'Apr_2002' 'May_2002' 'Jun_2002'
#  'Jul_2002' 'Aug_2002' 'Sep_2002' 'Oct_2002' 'Nov_2002' 'Dec_2002'
#  'Jan_2003' 'Feb_2003' 'Mar_2003' 'Apr_2003' 'May_2003' 'Jun_2003'
#  'Jul_2003' 'Aug_2003' 'Sep_2003' 'Oct_2003' 'Nov_2003' 'Dec_2003'
#  'Jan_2004' 'Feb_2004' 'Mar_2004' 'Apr_2004' 'May_2004' 'Jun_2004'
# ...

# %%
a1.by_year(product="Education",cl=country_list,start="Jan_2010",stop="Jul_2010")
# Out:
# INFO:root:You have chosen the following countries : ['Bahamas', 'Barbados', 'Belize', 'British_virgin_islands', 'Canada', 'Costa_rica', 'Dominica', 'El_salvador', 'Guatemala', 'Haiti', 'Honduras', 'Mexico', 'Nicaragua', 'Panama', 'United_states']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2010 to Jun_2010
#                           Jan_2010    Feb_2010    Mar_2010    Apr_2010  \
# Bahamas                        NaN         NaN         NaN         NaN
# Barbados                       NaN         NaN         NaN         NaN
# Belize                         NaN   88.614319         NaN         NaN
# British_virgin_islands         NaN         NaN         NaN         NaN
# Canada                         NaN         NaN         NaN         NaN
# Costa_rica               57.068000   60.048000   60.316000   60.279000
# Dominica                       NaN         NaN         NaN         NaN
# ...

# %%
from analysis import Analyser
import matplotlib.pyplot as plt
from plotter import Plotter

analyser = Analyser()

country = "United_States"
start_time = "Jan_2022"
stop_time = "Dec_2022"

inflation_data = analyser.all_products_inflation(country,
                                                 start_time, stop_time)

plotter = Plotter(inflation_data, title=f"Inflation Rate by of products in {country}")

bar_chart = plotter.plot_bar()

plt.show()
# Out:
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Misc_Goods_Services
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Recreation_Culture
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Food
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Clothing
# INFO:root:You have chosen the time data from Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# ...

# %%
from analysis import Analyser
from plotter import Plotter
import matplotlib.pyplot as plt

analyser = Analyser()

product = "Education"
country_list = ["United_States", "Canada"]
start_time = "Dec_2021"
stop_time = "Dec_2022"

data = analyser.set_datafile(product,country_list,
                            start_time,stop_time)

inflation_data = analyser.inflation_calculator(data)
            
plotter = Plotter(inflation_data, title="Inflation Rate by Country")

line_chart = plotter.plot_line()

plt.show()
# Out:
# INFO:root:You have chosen the following countries : ['United_states', 'Canada']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from Dec_2021 to Nov_2022

# %%
inflation_data.iloc[:,1:]
# Out:
#                Feb_2022_INF  Mar_2022_INF  Apr_2022_INF  May_2022_INF  \
# United_states           0.3          -0.0           0.3           0.5
# Canada                  0.0           0.0           0.0           0.0
#
#                Jun_2022_INF  Jul_2022_INF  Aug_2022_INF  Sep_2022_INF  \
# United_states           0.7           0.1           0.7           1.8
# Canada                  0.0           0.0           0.0           2.5
#
#                Oct_2022_INF  Nov_2022_INF
# United_states           0.1           0.3
# Canada                  0.0           0.0
