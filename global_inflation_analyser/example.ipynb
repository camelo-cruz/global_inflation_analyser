# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Example 1

# %%
from preprocessor import Preprocessor

preprocessor = Preprocessor() 

products_list = preprocessor.list_products()
print(f"Available products: {products_list}")
# Out:
# Available products: ['Transport', 'Food', 'Recreation_Culture', 'Housing_Energy', 'Restaurants_Hotels', 'Misc_Goods_Services', 'Education', 'Alcoholic_Beverages', 'Health', 'Clothing', 'Communication']

# %% [markdown]
# ### Example 2

# %%
from preprocessor import Preprocessor

preprocessor = Preprocessor() 

selected_product = "Education"

product_data = preprocessor.by_product(selected_product)

print("Data for the selected product:")
product_data.head()
# Out:
# INFO:root:You have chosen Education
# Data for the selected product:
#                      Jan_2000  Feb_2000  Mar_2000  Apr_2000  May_2000  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN
# Albania                   NaN       NaN       NaN       NaN       NaN
# Antigua_and_barbuda       NaN       NaN       NaN       NaN       NaN
# Argentina                 NaN       NaN       NaN       NaN       NaN
# Armenia                   NaN       NaN       NaN       NaN       NaN
#
#                      Jun_2000  Jul_2000  Aug_2000  Sep_2000  Oct_2000  ...  \
# Afghanistan               NaN       NaN       NaN       NaN       NaN  ...
# Albania                   NaN       NaN       NaN       NaN       NaN  ...
# Antigua_and_barbuda       NaN       NaN       NaN       NaN       NaN  ...
# Argentina                 NaN       NaN       NaN       NaN       NaN  ...
# Armenia                   NaN       NaN       NaN       NaN       NaN  ...
#
#                        Aug_2022    Sep_2022    Oct_2022    Nov_2022  \
# Afghanistan                 NaN         NaN         NaN         NaN
# Albania              100.897488  102.554938  102.171331  102.486652
# Antigua_and_barbuda   99.770000   99.880000   99.880000   99.880000
# Argentina            745.726800  772.997400  827.900400  859.055300
# Armenia              138.335173  144.799196  144.799196  144.799196
#
#                        Dec_2022    Jan_2023    Feb_2023     Mar_2023  \
# Afghanistan                 NaN         NaN         NaN          NaN
# Albania              102.849186  102.886616  102.886616   102.795764
# Antigua_and_barbuda   99.880000         NaN         NaN          NaN
# Argentina            892.622200  902.068600  930.486800  1201.125800
# Armenia              144.799196  144.799196  144.799196   144.799196
#
#                         Apr_2023  May_2023
# Afghanistan                  NaN       NaN
# Albania               102.903842       NaN
# Antigua_and_barbuda          NaN       NaN
# Argentina            1261.527300       NaN
# Armenia               144.799196       NaN
#
# [5 rows x 281 columns]

# %% [markdown]
# ### Example 3

# %%
from preprocessor import Preprocessor

preprocessor = Preprocessor()

selected_product = "Food"

selected_countries = ["United_States","United_Kingdom","Canada","Germany","Spain"]

countries_data = preprocessor.by_country(selected_product, selected_countries)

print(f"Data for the selected countries: ")
countries_data.head()
# Out:
# INFO:root:You have chosen the following countries : ['United_states', 'United_kingdom', 'Canada', 'Germany', 'Spain']
# INFO:root:You have chosen Food
# Data for the selected countries:
#                  Jan_2000   Feb_2000   Mar_2000   Apr_2000   May_2000  \
# United_states   77.049417  77.049417  77.095747  77.142077  77.605401
# United_kingdom  65.700000  65.700000  65.200000  65.000000  65.700000
# Canada          91.700000  91.400000  91.900000  92.100000  93.000000
# Germany         69.102170  69.509140  69.020780  69.427750  69.671920
# Spain           60.275540  59.865990  59.824390  60.030410  59.862980
#
#                 Jun_2000   Jul_2000   Aug_2000   Sep_2000   Oct_2000  ...  \
# United_states   77.51273  77.976054  78.254046  78.300377  78.346707  ...
# United_kingdom  65.90000  66.400000  65.900000  66.100000  66.000000  ...
# Canada          93.80000  94.400000  93.900000  92.800000  92.500000  ...
# Germany         69.67192  69.427750  68.776600  68.532430  68.451030  ...
# Spain           59.78930  60.177280  60.506620  60.941230  61.115680  ...
#
#                   Aug_2022    Sep_2022   Oct_2022    Nov_2022    Dec_2022  \
# United_states   136.722424  137.495859  138.34512  138.216215  138.721005
# United_kingdom  118.300000  119.600000  122.00000  123.400000  125.400000
# Canada          171.400000  173.100000  173.00000  175.700000  176.300000
# Germany         118.900000  121.000000  122.60000  124.000000  125.100000
# Spain           113.481000  114.017000  116.61000  117.185000  119.044000
#
#                   Jan_2023    Feb_2023    Mar_2023    Apr_2023  May_2023
# United_states   139.656926  140.129219  139.857326  140.047976       NaN
# United_kingdom  126.100000  128.800000  130.200000  132.100000       NaN
# Canada          179.900000  181.200000  181.700000  182.000000       NaN
# Germany         127.000000  129.900000  131.500000  130.800000       NaN
# Spain           119.498000  121.849000  123.144000  123.474000       NaN
#
# [5 rows x 281 columns]

# %% [markdown]
# ### Example 4

# %%
from preprocessor import Preprocessor

preprocessor = Preprocessor()

years_list = preprocessor.list_years()

print(f"Available years: \nStart: {years_list[:5]}\nEnd: {years_list[-5:]}")
# Out:
# INFO:root:You have chosen the following countries : ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czech_rep.', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Russian_federation', 'Serbia', 'Spain', 'Switzerland', 'Ukraine', 'United_kingdom']
# INFO:root:You have chosen Education
# Available years:
# Start: ['Jan_2000' 'Feb_2000' 'Mar_2000' 'Apr_2000' 'May_2000']
# End: ['Jan_2023' 'Feb_2023' 'Mar_2023' 'Apr_2023' 'May_2023']

# %% [markdown]
# ### Example 5

# %%
from preprocessor import Preprocessor

preprocessor = Preprocessor()

selected_product = "Clothing"

selected_countries = ["United_States","United_Kingdom","Canada","Germany","Spain"]

start_year = "Mar_2012"
stop_year = "Sep_2018"

years_data = preprocessor.by_year(selected_product, selected_countries, start_year, stop_year)

print(f"Data for the selected years: \n")
years_data.head()
# Out:
# INFO:root:You have chosen the following countries : ['United_states', 'United_kingdom', 'Canada', 'Germany', 'Spain']
# INFO:root:You have chosen Clothing
# INFO:root:You have chosen the time data from                          Mar_2012 to Aug_2018
# Data for the selected years:
#                   Mar_2012    Apr_2012    May_2012    Jun_2012    Jul_2012  \
# United_states   106.055897  107.091317  106.693648  104.367921  101.746058
# United_kingdom   99.600000   99.800000   99.700000   95.500000   93.000000
# Canada                 NaN         NaN         NaN         NaN         NaN
# Germany          97.626800   98.278890   97.533650   95.856850   91.758020
# Spain            89.912000   98.799000  100.917000   99.987000   87.813000
#
#                   Aug_2012    Sep_2012    Oct_2012    Nov_2012    Dec_2012  \
# United_states   102.510724  107.163235  109.371565  108.165868  104.921061
# United_kingdom   95.600000  100.100000  101.300000  101.900000  100.400000
# Canada                 NaN         NaN         NaN         NaN         NaN
# Germany          93.527970   98.278890   99.862530   99.396750   97.906270
# Spain            86.829000   90.362000   99.811000  104.886000  103.207000
#
#                 ...    Nov_2017    Dec_2017    Jan_2018    Feb_2018  Mar_2018  \
# United_states   ...  105.134702  101.416078  102.658792  106.193389  107.8930
# United_kingdom  ...  106.800000  105.800000  101.700000  103.400000  104.1000
# Canada          ...  104.300000  100.800000  100.000000  102.000000  104.0000
# Germany         ...  102.033600  100.657500   94.956150   96.823820  101.7387
# Spain           ...  107.568000  105.375000   89.230000   87.858000   91.6790
#
#                   Apr_2018    May_2018    Jun_2018    Jul_2018    Aug_2018
# United_states   108.638628  107.745989  105.438242  103.040596  102.769843
# United_kingdom  104.500000  104.700000  102.500000   98.800000  101.800000
# Canada          105.500000  104.700000  103.300000  101.900000  102.600000
# Germany         102.426800  101.738700   99.576180   94.268070   96.528930
# Spain           101.096000  103.676000  102.414000   89.517000   88.420000
#
# [5 rows x 78 columns]

# %% [markdown]
# ### Example 6

# %%
from analysis import Analyser

analyser = Analyser()

product = "Housing_Energy"
country_list = ["United_States","United_Kingdom","Canada","Germany","Spain"]
start_time = "Dec_2019"
stop_time = "Dec_2022"

data = analyser.set_datafile(product, country_list, start_time, stop_time)

inflation_result = analyser.inflation_calculator(data)

print("Inflation Rate:")
inflation_result.head()
# Out:
# INFO:root:You have chosen the following countries : ['United_states', 'United_kingdom', 'Canada', 'Germany', 'Spain']
# INFO:root:You have chosen Housing_Energy
# INFO:root:You have chosen the time data from                          Dec_2019 to Nov_2022
# Inflation Rate:
#                 Jan_2020_INF  Feb_2020_INF  Mar_2020_INF  Apr_2020_INF  \
# United_states            0.4           0.1           0.1           0.1
# United_kingdom           0.1           0.0           0.0           0.2
# Canada                   0.1           0.1          -0.2          -0.4
# Germany                  0.5           0.1           0.1           0.1
# Spain                    1.0          -1.2          -2.0          -2.0
#
#                 May_2020_INF  Jun_2020_INF  Jul_2020_INF  Aug_2020_INF  \
# United_states            0.2           0.3           0.2           0.1
# United_kingdom           0.1           0.1           0.2           0.1
# Canada                  -0.4           0.6          -0.0           0.3
# Germany                  0.0           0.0          -0.4           0.1
# Spain                    0.1           1.7           0.5           0.3
#
#                 Sep_2020_INF  Oct_2020_INF  ...  Feb_2022_INF  Mar_2022_INF  \
# United_states            0.2           0.1  ...           0.4           0.6
# United_kingdom           0.1          -0.5  ...           0.2           0.4
# Canada                   0.3           0.7  ...           0.6           0.8
# Germany                 -0.1           0.1  ...           0.7           1.8
# Spain                    0.8          -1.2  ...           0.6           9.7
#
#                 Apr_2022_INF  May_2022_INF  Jun_2022_INF  Jul_2022_INF  \
# United_states            0.5           0.9           1.1           0.5
# United_kingdom           5.1           0.3           0.2           0.4
# Canada                   1.0           0.8           0.4           0.6
# Germany                  0.3           0.7           0.6           0.1
# Spain                   -7.7          -0.7           3.4           2.6
#
#                 Aug_2022_INF  Sep_2022_INF  Oct_2022_INF  Nov_2022_INF
# United_states            0.8           0.8           0.5           0.5
# United_kingdom           0.2           0.3           3.4           0.2
# Canada                   0.0           0.6           0.9           0.8
# Germany                  0.7           1.1           1.4           0.4
# Spain                    3.6          -5.2          -6.6          -3.5
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Example 7

# %%
from analysis import Analyser

analyser = Analyser()

country = "Spain"
start_time = "Jan_2019"
stop_time = "Dec_2022"

# Calculate inflation rate for all products in the specified country and time period
inflation_by_product = analyser.all_products_inflation(country, start_time, stop_time)

print("Inflation Rate for All Products in", country)
inflation_by_product
# Out:
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Transport
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Food
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Recreation_Culture
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Housing_Energy
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Restaurants_Hotels
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Misc_Goods_Services
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Alcoholic_Beverages
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Health
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Clothing
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# INFO:root:You have chosen the following countries : ['Spain']
# INFO:root:You have chosen Communication
# INFO:root:You have chosen the time data from                          Jan_2019 to Nov_2022
# Inflation Rate for All Products in Spain
#                      Feb_2019_INF  Mar_2019_INF  Apr_2019_INF  May_2019_INF  \
# Transport                     1.5           1.1           1.3           0.5
# Food                          0.3          -0.4          -0.0           0.4
# Recreation_Culture            0.7           0.3           0.9          -1.5
# Housing_Energy               -1.1          -0.8          -0.2          -0.5
# Restaurants_Hotels            0.5           0.6           0.9           0.4
# Misc_Goods_Services           0.4           0.1           0.2           0.0
# Education                    -0.0          -0.0           0.0           0.0
# Alcoholic_Beverages           0.3           0.1          -0.0           0.1
# Health                        0.0           0.1           0.1           0.1
# Clothing                     -1.5           4.4          10.5           2.4
# Communication                 0.8          -0.2          -0.1           0.1
#
#                      Jun_2019_INF  Jul_2019_INF  Aug_2019_INF  Sep_2019_INF  \
# Transport                    -1.4           0.3          -0.1           0.2
# Food                          0.4          -0.3           0.1          -0.1
# Recreation_Culture            1.7           1.6           1.1          -3.1
# Housing_Energy               -0.6           0.7          -1.0          -0.5
# Restaurants_Hotels            0.3           0.4           0.1          -0.0
# Misc_Goods_Services           0.3          -0.4           0.3           0.1
# Education                     0.0           0.0           0.0           0.1
# Alcoholic_Beverages          -0.1          -0.0           0.0          -0.0
# Health                        0.0           0.1          -0.1           0.1
# Clothing                     -1.3         -12.6          -1.2           5.4
# Communication                -0.2           0.1           0.2           0.1
#
#                      Oct_2019_INF  Nov_2019_INF  ...  Feb_2022_INF  \
# Transport                    -0.2          -0.1  ...           2.7
# Food                          1.5          -0.0  ...           0.8
# Recreation_Culture           -0.9          -0.4  ...           0.7
# Housing_Energy                1.1          -0.4  ...           0.6
# Restaurants_Hotels           -0.4          -0.5  ...           0.8
# Misc_Goods_Services           0.1           0.2  ...           0.6
# Education                     0.6           0.0  ...           0.0
# Alcoholic_Beverages           0.0          -0.0  ...           0.9
# Health                        0.1           0.1  ...           0.1
# Clothing                     11.2           4.9  ...          -1.5
# Communication                -0.3          -0.1  ...          -0.1
#
#                      Mar_2022_INF  Apr_2022_INF  May_2022_INF  Jun_2022_INF  \
# Transport                     7.1          -4.8           2.9           4.9
# Food                          1.2           3.4           1.2           1.8
# Recreation_Culture           -0.3           1.5          -0.7           1.2
# Housing_Energy                9.7          -7.7          -0.7           3.4
# Restaurants_Hotels            1.0           1.7           0.7           1.3
# Misc_Goods_Services           0.5           0.5           0.3           0.5
# Education                    -0.0          -0.0           0.0           0.0
# Alcoholic_Beverages           0.5           0.3           0.0           0.4
# Health                        0.3           0.2          -0.0           0.0
# Clothing                      3.8           8.5           2.7          -0.6
# Communication                 0.0           0.5          -0.1          -0.1
#
#                      Jul_2022_INF  Aug_2022_INF  Sep_2022_INF  Oct_2022_INF  \
# Transport                    -1.9          -3.7          -1.4           1.4
# Food                          0.3           0.5           0.5           2.3
# Recreation_Culture            1.2           1.0          -1.4          -0.2
# Housing_Energy                2.6           3.6          -5.2          -6.6
# Restaurants_Hotels            0.9           0.4           0.2           0.2
# Misc_Goods_Services          -0.0           0.4           0.1           0.5
# Education                     0.0           0.0           0.7           0.7
# Alcoholic_Beverages           0.4           0.3           0.1           0.2
# Health                        0.1          -0.0           0.1          -0.0
# Clothing                    -10.2          -0.6           3.6           8.5
# Communication                -2.0          -0.0          -0.2          -0.1
#
#                      Nov_2022_INF
# Transport                    -0.0
# Food                          0.5
# Recreation_Culture           -0.1
# Housing_Energy               -3.5
# Restaurants_Hotels           -0.3
# Misc_Goods_Services           0.4
# Education                     0.1
# Alcoholic_Beverages           0.4
# Health                        0.2
# Clothing                      3.3
# Communication                -0.0
#
# [11 rows x 46 columns]

# %% [markdown]
# ### Example 8

# %%
from analysis import Analyser
from plotter import Plotter
import matplotlib.pyplot as plt

analyser = Analyser()

country = "United_States"
start_time = "Jan_2022"
stop_time = "Dec_2022"

inflation_data = analyser.all_products_inflation(country,
                                                 start_time, stop_time)

plotter = Plotter(inflation_data, title=f"Inflation Rate by of products in {country}")

bar_chart = plotter.plot_bar()

plt.show()
# Out:
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Transport
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Food
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Recreation_Culture
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Housing_Energy
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Restaurants_Hotels
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Misc_Goods_Services
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Education
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Alcoholic_Beverages
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Health
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Clothing
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022
# INFO:root:You have chosen the following countries : ['United_states']
# INFO:root:You have chosen Communication
# INFO:root:You have chosen the time data from                          Jan_2022 to Nov_2022

# %% [markdown]
# ### Example 9

# %%
from analysis import Analyser
from plotter import Plotter
import matplotlib.pyplot as plt

analyser = Analyser()

product = "Housing_Energy"
country_list = ["United_States","United_Kingdom","Canada","Germany","Spain"]
# Enter one time period before the desired input, 
# e.g. enter Dec_2021 if you want data starting from Jan_2022
start_time = "Dec_2019" 
stop_time = "Dec_2022"

data = analyser.set_datafile(product,country_list,
                            start_time,stop_time)

inflation_data = analyser.inflation_calculator(data)
            
plotter = Plotter(inflation_data, title="Inflation Rate by Country")

line_chart = plotter.plot_line()

plt.show()
# Out:
# INFO:root:You have chosen the following countries : ['United_states', 'United_kingdom', 'Canada', 'Germany', 'Spain']
# INFO:root:You have chosen Housing_Energy
# INFO:root:You have chosen the time data from                          Dec_2019 to Nov_2022
